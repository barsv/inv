# %%
from plotly.subplots import make_subplots
import plotly.graph_objects as go
import forecast
from quote_chart import create_chart_app

start_date = '2024-01-02 00:00' # default start date.
selected_period = '1T' # default period. allowed values are as periods in pandas.resample. for example, 1T == 1 minute.
# load data for the default time period.
candles_df = forecast.get_df('BTCUSD', start_date, selected_period)


def on_period_change(button_id):
    global candles_df, selected_period
    if button_id == 'one-min':
        selected_period = '1T'
        candles_df = forecast.get_df('BTCUSD', start_date, selected_period)
    elif button_id == 'five-min':
        selected_period = '5T'
        candles_df = forecast.get_df('BTCUSD', start_date, selected_period)
    elif button_id == 'one-hour':
        selected_period = '1H'
        candles_df = forecast.get_df('BTCUSD', start_date, selected_period)
    elif button_id == 'one-day':
        selected_period = 'D'
        candles_df = forecast.get_df('BTCUSD', start_date, selected_period)


def create_figure(x0, x1):
    print('create_figure started')
    # slice dataframe so that there will be enough data to plot the chart and also have data on the left and right so 
    # that when the user starts to zoom/pan he will see data.
    if x0 is not None:
        delta = x1 - x0
        df = candles_df[x0-delta:x1+delta].copy()
    else:
        # by default show last 100 candles.
        df = candles_df[-100:].copy()
    # define multiple panes. The top pane will be for the main price chart with candles. The second pane is for volumes.
    fig = make_subplots(rows=2, cols=1, shared_xaxes=True, 
                vertical_spacing=0.03,
                row_heights=[0.8, 0.2],
                specs=[[{"secondary_y": True}], [{"secondary_y": True}]])
    fig.add_trace(go.Scatter(x=df.index, y=df['high'] * 1.001, mode='lines', line=dict(color='red'), name='highs'))
    fig.add_trace(go.Scatter(x=df.index, y=df['low'] * 0.999, mode='lines', line=dict(color='steelblue'), name='lows'))
    # plot the main chart with price candles.
    fig.add_trace(go.Candlestick(x=df.index,
                                 open=df['open'],
                                 high=df['high'],
                                 low=df['low'],
                                 close=df['close'],
                                 name=selected_period), row=1, col=1)
    fig.add_trace(go.Bar(x=df.index, y=df['volume'], name='Volume'), row=2, col=1)
    # set the default dragmode to pan, remove the range slider because i use zoom/pan instead of it.
    fig.update_layout(
        dragmode='pan',
        xaxis_rangeslider_visible=False,
        width=1200, # px
        height=600,
        margin=dict(l=10, r=20, t=20, b=20),
        yaxis=dict(side='right'),
        yaxis2=dict(side='right'),
        yaxis3=dict(side='right')
        )
    print('create_figure completed')
    return fig


app = create_chart_app(create_figure, on_period_change)
app.run_server(debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# relayoutData: None
# update_graph started
# create_figure started
# create_figure completed
# relayoutData: None
# update_graph started
# create_figure started
# create_figure completed
# Server received: scrolling
# relayoutData: {'xaxis.range[0]': '2024-05-29 22:24:30.000', 'xaxis.range[1]': '2024-05-29 23:59:30', 'yaxis.range[0]': 67522.95, 'yaxis.range[1]': 67788.05}
# relayout_store: {'xaxis.range[0]': '2024-05-29 22:24:30.000', 'xaxis.range[1]': '2024-05-29 23:59:30', 'yaxis.range[0]': 67522.95, 'yaxis.range[1]': 67788.05}
# update_graph started
# no update_graph because of scrolling
# relayoutData: {'xaxis.range[0]': '2024-05-29 22:24:30.000', 'xaxis.range[1]': '2024-05-29 23:59:30', 'yaxis.range[0]': 67522.95, 'yaxis.range[1]': 67788.05}
# no_updates
# Server received: not scrolling
# update_graph started
# create_figure started
# create_figure completed
# Server received: scrolling
# relayoutData: {'xaxis.range[0]': '2024-05-29 22:14:45.750', 'xaxis.range[1]': '2024-05-29 23:59:30', 'yaxis.range[0]': 67521.025, 'yaxis.range[1]': 67828.475}
# relayout_store: {'xaxis.range[0]': '2024-05-29 22:14:45.750', 'xaxis.range[1]': '2024-05-29 23:59:30', 'yaxis.range[0]': 67521.025, 'yaxis.range[1]': 67828.475}
# relayoutData: {'xaxis.range[0]': '2024-05-29 22:09:31.537', 'xaxis.range[1]': '2024-05-29 23:59:30', 'yaxis.range[0]': 67521.025, 'yaxis.range[1]': 67828.475}
# relayout_store: {'xaxis.range[0]': '2024-05-29 22:09:31.537', 'xaxis.range[1]': '2024-05-29 23:59:30', 'yaxis.range[0]': 67521.025, 'yaxis.range[1]': 67828.475}
# relayoutData: {'xaxis.range[0]': '2024-05-29 22:04:01.613', 'xaxis.range[1]': '2024-05-29 23:59:30', 'yaxis.range[0]': 67521.025, 'yaxis.range[1]': 67828.475}
# relayout_store: {'xaxis.range[0]': '2024-05-29 22:04:01.613', 'xaxis.range[1]': '2024-05-29 23:59:30', 'yaxis.range[0]': 67521.025, 'yaxis.range[1]': 67828.475}
# update_graph started
# no update_graph because of scrolling
# relayoutData: {'xaxis.range[0]': '2024-05-29 21:58:15.193', 'xaxis.range[1]': '2024-05-29 23:59:30', 'yaxis.range[0]': 67521.025, 'yaxis.range[1]': 67828.475}
# relayout_store: {'xaxis.range[0]': '2024-05-29 21:58:15.193', 'xaxis.range[1]': '2024-05-29 23:59:30', 'yaxis.range[0]': 67521.025, 'yaxis.range[1]': 67828.475}
# update_graph started
# no update_graph because of scrolling
# Server received: not scrolling
# update_graph started
# create_figure started
# create_figure completed
# Server received: scrolling
# relayoutData: {'xaxis.range[0]': '2024-05-29 21:45:49.524', 'xaxis.range[1]': '2024-05-29 23:59:30', 'yaxis.range[0]': 67521.025, 'yaxis.range[1]': 67828.475}
# relayout_store: {'xaxis.range[0]': '2024-05-29 21:45:49.524', 'xaxis.range[1]': '2024-05-29 23:59:30', 'yaxis.range[0]': 67521.025, 'yaxis.range[1]': 67828.475}
# update_graph started
# no update_graph because of scrolling
# Server received: not scrolling
# update_graph started
# create_figure started
# create_figure completed
# Server received: scrolling
# relayoutData: {'xaxis.range[0]': '2024-05-29 21:39:08.500', 'xaxis.range[1]': '2024-05-29 23:59:30', 'yaxis.range[0]': 67521.025, 'yaxis.range[1]': 67828.475}
# relayout_store: {'xaxis.range[0]': '2024-05-29 21:39:08.500', 'xaxis.range[1]': '2024-05-29 23:59:30', 'yaxis.range[0]': 67521.025, 'yaxis.range[1]': 67828.475}
# relayoutData: {'xaxis.range[0]': '2024-05-29 21:24:45.296', 'xaxis.range[1]': '2024-05-29 23:59:30', 'yaxis.range[0]': 67273.225, 'yaxis.range[1]': 67840.275}
# relayout_store: {'xaxis.range[0]': '2024-05-29 21:24:45.296', 'xaxis.range[1]': '2024-05-29 23:59:30', 'yaxis.range[0]': 67273.225, 'yaxis.range[1]': 67840.275}
# relayoutData: {'xaxis.range[0]': '2024-05-29 21:17:01.060', 'xaxis.range[1]': '2024-05-29 23:59:30', 'yaxis.range[0]': 67273.225, 'yaxis.range[1]': 67840.275}
# relayout_store: {'xaxis.range[0]': '2024-05-29 21:17:01.060', 'xaxis.range[1]': '2024-05-29 23:59:30', 'yaxis.range[0]': 67273.225, 'yaxis.range[1]': 67840.275}
# update_graph started
# no update_graph because of scrolling
# Server received: not scrolling
# update_graph started
# create_figure started
# create_figure completed
# Server received: scrolling
# relayoutData: {'xaxis.range[0]': '2024-05-29 21:25:08.507', 'xaxis.range[1]': '2024-05-29 23:59:30', 'yaxis.range[0]': 67273.225, 'yaxis.range[1]': 67840.275}
# relayout_store: {'xaxis.range[0]': '2024-05-29 21:25:08.507', 'xaxis.range[1]': '2024-05-29 23:59:30', 'yaxis.range[0]': 67273.225, 'yaxis.range[1]': 67840.275}
# relayoutData: {'xaxis.range[0]': '2024-05-29 21:32:51.581', 'xaxis.range[1]': '2024-05-29 23:59:30', 'yaxis.range[0]': 67492.675, 'yaxis.range[1]': 67829.825}
# relayout_store: {'xaxis.range[0]': '2024-05-29 21:32:51.581', 'xaxis.range[1]': '2024-05-29 23:59:30', 'yaxis.range[0]': 67492.675, 'yaxis.range[1]': 67829.825}
# relayoutData: {'xaxis.range[0]': '2024-05-29 21:40:11.501', 'xaxis.range[1]': '2024-05-29 23:59:30', 'yaxis.range[0]': 67521.025, 'yaxis.range[1]': 67828.475}
# relayout_store: {'xaxis.range[0]': '2024-05-29 21:40:11.501', 'xaxis.range[1]': '2024-05-29 23:59:30', 'yaxis.range[0]': 67521.025, 'yaxis.range[1]': 67828.475}
# update_graph started
# no update_graph because of scrolling
# relayoutData: {'xaxis.range[0]': '2024-05-29 21:47:09.425', 'xaxis.range[1]': '2024-05-29 23:59:30', 'yaxis.range[0]': 67521.025, 'yaxis.range[1]': 67828.475}
# relayout_store: {'xaxis.range[0]': '2024-05-29 21:47:09.425', 'xaxis.range[1]': '2024-05-29 23:59:30', 'yaxis.range[0]': 67521.025, 'yaxis.range[1]': 67828.475}
# update_graph started
# no update_graph because of scrolling
# Server received: not scrolling
# update_graph started
# create_figure started
# create_figure completed
# Server received: scrolling
# relayoutData: {'xaxis.range[0]': '2024-05-29 21:40:32.396', 'xaxis.range[1]': '2024-05-29 23:59:30', 'yaxis.range[0]': 67521.025, 'yaxis.range[1]': 67828.475}
# relayout_store: {'xaxis.range[0]': '2024-05-29 21:40:32.396', 'xaxis.range[1]': '2024-05-29 23:59:30', 'yaxis.range[0]': 67521.025, 'yaxis.range[1]': 67828.475}
# update_graph started
# no update_graph because of scrolling
# Server received: not scrolling
# update_graph started
# create_figure started
# create_figure completed
# Server received: scrolling
# relayoutData: {'xaxis.range[0]': '2024-05-29 21:54:05.312', 'xaxis.range[1]': '2024-05-29 23:59:30', 'yaxis.range[0]': 67521.025, 'yaxis.range[1]': 67828.475}
# relayout_store: {'xaxis.range[0]': '2024-05-29 21:54:05.312', 'xaxis.range[1]': '2024-05-29 23:59:30', 'yaxis.range[0]': 67521.025, 'yaxis.range[1]': 67828.475}
# update_graph started
# no update_graph because of scrolling
# Server received: not scrolling
# update_graph started
# create_figure started
# create_figure completed
# Server received: scrolling
# relayoutData: {'xaxis.range[0]': '2024-05-29 22:00:21.546', 'xaxis.range[1]': '2024-05-29 23:59:30', 'yaxis.range[0]': 67521.025, 'yaxis.range[1]': 67828.475}
# relayout_store: {'xaxis.range[0]': '2024-05-29 22:00:21.546', 'xaxis.range[1]': '2024-05-29 23:59:30', 'yaxis.range[0]': 67521.025, 'yaxis.range[1]': 67828.475}
# update_graph started
# no update_graph because of scrolling
# relayoutData: {'xaxis.range[0]': '2024-05-29 22:06:18.968', 'xaxis.range[1]': '2024-05-29 23:59:30', 'yaxis.range[0]': 67521.025, 'yaxis.range[1]': 67828.475}
# relayout_store: {'xaxis.range[0]': '2024-05-29 22:06:18.968', 'xaxis.range[1]': '2024-05-29 23:59:30', 'yaxis.range[0]': 67521.025, 'yaxis.range[1]': 67828.475}
# update_graph started
# no update_graph because of scrolling
# relayoutData: {'xaxis.range[0]': '2024-05-29 22:11:58.519', 'xaxis.range[1]': '2024-05-29 23:59:30', 'yaxis.range[0]': 67521.025, 'yaxis.range[1]': 67828.475}
# relayout_store: {'xaxis.range[0]': '2024-05-29 22:11:58.519', 'xaxis.range[1]': '2024-05-29 23:59:30', 'yaxis.range[0]': 67521.025, 'yaxis.range[1]': 67828.475}
# update_graph started
# no update_graph because of scrolling
# Server received: not scrolling
# update_graph started
# create_figure started
# create_figure completed
# Server received: scrolling
# relayoutData: {'xaxis.range[0]': '2024-05-29 22:00:57.241', 'xaxis.range[1]': '2024-05-29 23:59:30', 'yaxis.range[0]': 67521.025, 'yaxis.range[1]': 67828.475}
# relayout_store: {'xaxis.range[0]': '2024-05-29 22:00:57.241', 'xaxis.range[1]': '2024-05-29 23:59:30', 'yaxis.range[0]': 67521.025, 'yaxis.range[1]': 67828.475}
# relayoutData: {'xaxis.range[0]': '2024-05-29 21:48:48.183', 'xaxis.range[1]': '2024-05-29 23:59:30', 'yaxis.range[0]': 67521.025, 'yaxis.range[1]': 67828.475}
# relayout_store: {'xaxis.range[0]': '2024-05-29 21:48:48.183', 'xaxis.range[1]': '2024-05-29 23:59:30', 'yaxis.range[0]': 67521.025, 'yaxis.range[1]': 67828.475}
# relayoutData: {'xaxis.range[0]': '2024-05-29 21:35:24.396', 'xaxis.range[1]': '2024-05-29 23:59:30', 'yaxis.range[0]': 67520.5, 'yaxis.range[1]': 67828.5}
# relayout_store: {'xaxis.range[0]': '2024-05-29 21:35:24.396', 'xaxis.range[1]': '2024-05-29 23:59:30', 'yaxis.range[0]': 67520.5, 'yaxis.range[1]': 67828.5}
# update_graph started
# no update_graph because of scrolling
# Server received: not scrolling
# update_graph started
# create_figure started
# create_figure completed
# Server received: scrolling
# relayoutData: {'xaxis.range[0]': '2024-05-29 21:28:12.115', 'xaxis.range[1]': '2024-05-29 23:59:30', 'yaxis.range[0]': 67273.225, 'yaxis.range[1]': 67840.275}
# relayout_store: {'xaxis.range[0]': '2024-05-29 21:28:12.115', 'xaxis.range[1]': '2024-05-29 23:59:30', 'yaxis.range[0]': 67273.225, 'yaxis.range[1]': 67840.275}
# relayoutData: {'xaxis.range[0]': '2024-05-29 21:20:38.220', 'xaxis.range[1]': '2024-05-29 23:59:30', 'yaxis.range[0]': 67273.225, 'yaxis.range[1]': 67840.275}
# relayout_store: {'xaxis.range[0]': '2024-05-29 21:20:38.220', 'xaxis.range[1]': '2024-05-29 23:59:30', 'yaxis.range[0]': 67273.225, 'yaxis.range[1]': 67840.275}
# relayoutData: {'xaxis.range[0]': '2024-05-29 21:12:41.631', 'xaxis.range[1]': '2024-05-29 23:59:30', 'yaxis.range[0]': 67273.225, 'yaxis.range[1]': 67840.275}
# relayout_store: {'xaxis.range[0]': '2024-05-29 21:12:41.631', 'xaxis.range[1]': '2024-05-29 23:59:30', 'yaxis.range[0]': 67273.225, 'yaxis.range[1]': 67840.275}
# update_graph started
# no update_graph because of scrolling
# Server received: not scrolling
# update_graph started
# create_figure started
# create_figure completed
# Server received: scrolling
# relayoutData: {'xaxis.range[0]': '2024-05-29 21:21:02.049', 'xaxis.range[1]': '2024-05-29 23:59:30', 'yaxis.range[0]': 67273.225, 'yaxis.range[1]': 67840.275}
# relayout_store: {'xaxis.range[0]': '2024-05-29 21:21:02.049', 'xaxis.range[1]': '2024-05-29 23:59:30', 'yaxis.range[0]': 67273.225, 'yaxis.range[1]': 67840.275}
# update_graph started
# no update_graph because of scrolling
# Server received: not scrolling
# update_graph started
# create_figure started
# create_figure completed
# Server received: scrolling
# relayoutData: {'xaxis.range[0]': '2024-05-29 21:28:57.446', 'xaxis.range[1]': '2024-05-29 23:59:30', 'yaxis.range[0]': 67273.225, 'yaxis.range[1]': 67840.275}
# relayout_store: {'xaxis.range[0]': '2024-05-29 21:28:57.446', 'xaxis.range[1]': '2024-05-29 23:59:30', 'yaxis.range[0]': 67273.225, 'yaxis.range[1]': 67840.275}
# relayoutData: {'xaxis.range[0]': '2024-05-29 21:43:38.119', 'xaxis.range[1]': '2024-05-29 23:59:30', 'yaxis.range[0]': 67521.025, 'yaxis.range[1]': 67828.475}
# relayout_store: {'xaxis.range[0]': '2024-05-29 21:43:38.119', 'xaxis.range[1]': '2024-05-29 23:59:30', 'yaxis.range[0]': 67521.025, 'yaxis.range[1]': 67828.475}
# update_graph started
# no update_graph because of scrolling
# Server received: not scrolling
# update_graph started
# create_figure started
# create_figure completed
# Server received: scrolling
# relayoutData: {'xaxis.range[0]': '2024-05-29 21:50:25.713', 'xaxis.range[1]': '2024-05-29 23:59:30', 'yaxis.range[0]': 67521.025, 'yaxis.range[1]': 67828.475}
# relayout_store: {'xaxis.range[0]': '2024-05-29 21:50:25.713', 'xaxis.range[1]': '2024-05-29 23:59:30', 'yaxis.range[0]': 67521.025, 'yaxis.range[1]': 67828.475}
# relayoutData: {'xaxis.range[0]': '2024-05-29 22:08:50.241', 'xaxis.range[1]': '2024-05-29 23:59:30', 'yaxis.range[0]': 67521.025, 'yaxis.range[1]': 67828.475}
# relayout_store: {'xaxis.range[0]': '2024-05-29 22:08:50.241', 'xaxis.range[1]': '2024-05-29 23:59:30', 'yaxis.range[0]': 67521.025, 'yaxis.range[1]': 67828.475}
# update_graph started
# no update_graph because of scrolling
# Server received: not scrolling
# update_graph started
# create_figure started
# create_figure completed
# Server received: scrolling
# relayoutData: {'xaxis.range[0]': '2024-05-29 21:57:29.665', 'xaxis.range[1]': '2024-05-29 23:59:30', 'yaxis.range[0]': 67521.025, 'yaxis.range[1]': 67828.475}
# relayout_store: {'xaxis.range[0]': '2024-05-29 21:57:29.665', 'xaxis.range[1]': '2024-05-29 23:59:30', 'yaxis.range[0]': 67521.025, 'yaxis.range[1]': 67828.475}
# relayoutData: {'xaxis.range[0]': '2024-05-29 21:51:23.648', 'xaxis.range[1]': '2024-05-29 23:59:30', 'yaxis.range[0]': 67521.025, 'yaxis.range[1]': 67828.475}
# relayout_store: {'xaxis.range[0]': '2024-05-29 21:51:23.648', 'xaxis.range[1]': '2024-05-29 23:59:30', 'yaxis.range[0]': 67521.025, 'yaxis.range[1]': 67828.475}
# relayoutData: {'xaxis.range[0]': '2024-05-29 21:44:59.330', 'xaxis.range[1]': '2024-05-29 23:59:30', 'yaxis.range[0]': 67521.025, 'yaxis.range[1]': 67828.475}
# relayout_store: {'xaxis.range[0]': '2024-05-29 21:44:59.330', 'xaxis.range[1]': '2024-05-29 23:59:30', 'yaxis.range[0]': 67521.025, 'yaxis.range[1]': 67828.475}
# relayoutData: {'xaxis.range[0]': '2024-05-29 21:38:15.796', 'xaxis.range[1]': '2024-05-29 23:59:30', 'yaxis.range[0]': 67520.5, 'yaxis.range[1]': 67828.5}
# relayout_store: {'xaxis.range[0]': '2024-05-29 21:38:15.796', 'xaxis.range[1]': '2024-05-29 23:59:30', 'yaxis.range[0]': 67520.5, 'yaxis.range[1]': 67828.5}
# update_graph started
# no update_graph because of scrolling
# Server received: not scrolling
# update_graph started
# create_figure started
# create_figure completed
# Server received: scrolling
# relayoutData: {'xaxis.range[0]': '2024-05-29 21:31:12.085', 'xaxis.range[1]': '2024-05-29 23:59:30', 'yaxis.range[0]': 67432.825, 'yaxis.range[1]': 67832.675}
# relayout_store: {'xaxis.range[0]': '2024-05-29 21:31:12.085', 'xaxis.range[1]': '2024-05-29 23:59:30', 'yaxis.range[0]': 67432.825, 'yaxis.range[1]': 67832.675}
# relayoutData: {'xaxis.range[0]': '2024-05-29 21:23:47.189', 'xaxis.range[1]': '2024-05-29 23:59:30', 'yaxis.range[0]': 67273.225, 'yaxis.range[1]': 67840.275}
# relayout_store: {'xaxis.range[0]': '2024-05-29 21:23:47.189', 'xaxis.range[1]': '2024-05-29 23:59:30', 'yaxis.range[0]': 67273.225, 'yaxis.range[1]': 67840.275}
# relayoutData: {'xaxis.range[0]': '2024-05-29 21:16:00.048', 'xaxis.range[1]': '2024-05-29 23:59:30', 'yaxis.range[0]': 67273.225, 'yaxis.range[1]': 67840.275}
# relayout_store: {'xaxis.range[0]': '2024-05-29 21:16:00.048', 'xaxis.range[1]': '2024-05-29 23:59:30', 'yaxis.range[0]': 67273.225, 'yaxis.range[1]': 67840.275}
# update_graph started
# no update_graph because of scrolling
# relayoutData: {'xaxis.range[0]': '2024-05-29 21:07:49.550', 'xaxis.range[1]': '2024-05-29 23:59:30', 'yaxis.range[0]': 67273.225, 'yaxis.range[1]': 67840.275}
# relayout_store: {'xaxis.range[0]': '2024-05-29 21:07:49.550', 'xaxis.range[1]': '2024-05-29 23:59:30', 'yaxis.range[0]': 67273.225, 'yaxis.range[1]': 67840.275}
# update_graph started
# no update_graph because of scrolling
# Server received: not scrolling
# update_graph started
# create_figure started
# create_figure completed
# Server received: scrolling
# relayoutData: {'xaxis.range[0]': '2024-05-29 21:24:33.843', 'xaxis.range[1]': '2024-05-29 23:59:30', 'yaxis.range[0]': 67273.225, 'yaxis.range[1]': 67840.275}
# relayout_store: {'xaxis.range[0]': '2024-05-29 21:24:33.843', 'xaxis.range[1]': '2024-05-29 23:59:30', 'yaxis.range[0]': 67273.225, 'yaxis.range[1]': 67840.275}
# relayoutData: {'xaxis.range[0]': '2024-05-29 21:39:40.217', 'xaxis.range[1]': '2024-05-29 23:59:30', 'yaxis.range[0]': 67521.025, 'yaxis.range[1]': 67828.475}
# relayout_store: {'xaxis.range[0]': '2024-05-29 21:39:40.217', 'xaxis.range[1]': '2024-05-29 23:59:30', 'yaxis.range[0]': 67521.025, 'yaxis.range[1]': 67828.475}
# update_graph started
# no update_graph because of scrolling
# relayoutData: {'xaxis.range[0]': '2024-05-29 21:46:39.706', 'xaxis.range[1]': '2024-05-29 23:59:30', 'yaxis.range[0]': 67521.025, 'yaxis.range[1]': 67828.475}
# relayout_store: {'xaxis.range[0]': '2024-05-29 21:46:39.706', 'xaxis.range[1]': '2024-05-29 23:59:30', 'yaxis.range[0]': 67521.025, 'yaxis.range[1]': 67828.475}
# update_graph started
# no update_graph because of scrolling
# Server received: not scrolling
# update_graph started
# create_figure started
# create_figure completed
# Server received: scrolling
# relayoutData: {'xaxis.range[0]': '2024-05-29 21:40:01.191', 'xaxis.range[1]': '2024-05-29 23:59:30', 'yaxis.range[0]': 67521.025, 'yaxis.range[1]': 67828.475}
# relayout_store: {'xaxis.range[0]': '2024-05-29 21:40:01.191', 'xaxis.range[1]': '2024-05-29 23:59:30', 'yaxis.range[0]': 67521.025, 'yaxis.range[1]': 67828.475}
# update_graph started
# no update_graph because of scrolling
# relayoutData: {'xaxis.range[0]': '2024-05-29 21:33:02.750', 'xaxis.range[1]': '2024-05-29 23:59:30', 'yaxis.range[0]': 67496.35, 'yaxis.range[1]': 67829.65}
# relayout_store: {'xaxis.range[0]': '2024-05-29 21:33:02.750', 'xaxis.range[1]': '2024-05-29 23:59:30', 'yaxis.range[0]': 67496.35, 'yaxis.range[1]': 67829.65}
# relayoutData: {'xaxis.range[0]': '2024-05-29 21:25:43.387', 'xaxis.range[1]': '2024-05-29 23:59:30', 'yaxis.range[0]': 67273.225, 'yaxis.range[1]': 67840.275}
# relayout_store: {'xaxis.range[0]': '2024-05-29 21:25:43.387', 'xaxis.range[1]': '2024-05-29 23:59:30', 'yaxis.range[0]': 67273.225, 'yaxis.range[1]': 67840.275}
# relayoutData: {'xaxis.range[0]': '2024-05-29 21:18:02.056', 'xaxis.range[1]': '2024-05-29 23:59:30', 'yaxis.range[0]': 67273.225, 'yaxis.range[1]': 67840.275}
# relayout_store: {'xaxis.range[0]': '2024-05-29 21:18:02.056', 'xaxis.range[1]': '2024-05-29 23:59:30', 'yaxis.range[0]': 67273.225, 'yaxis.range[1]': 67840.275}
# relayoutData: {'xaxis.range[0]': '2024-05-29 21:09:57.658', 'xaxis.range[1]': '2024-05-29 23:59:30', 'yaxis.range[0]': 67273.225, 'yaxis.range[1]': 67840.275}
# relayout_store: {'xaxis.range[0]': '2024-05-29 21:09:57.658', 'xaxis.range[1]': '2024-05-29 23:59:30', 'yaxis.range[0]': 67273.225, 'yaxis.range[1]': 67840.275}
# update_graph started
# no update_graph because of scrolling
# Server received: not scrolling
# update_graph started
# create_figure started
# create_figure completed
# Server received: scrolling
# relayoutData: {'xaxis.range[0]': '2024-05-29 21:34:08.487', 'xaxis.range[1]': '2024-05-29 23:59:30', 'yaxis.range[0]': 67520.5, 'yaxis.range[1]': 67828.5}
# relayout_store: {'xaxis.range[0]': '2024-05-29 21:34:08.487', 'xaxis.range[1]': '2024-05-29 23:59:30', 'yaxis.range[0]': 67520.5, 'yaxis.range[1]': 67828.5}
# update_graph started
# no update_graph because of scrolling
# Server received: not scrolling
# update_graph started
# create_figure started
# create_figure completed
# Server received: scrolling
# relayoutData: {'xaxis.range[0]': '2024-05-29 21:48:18.833', 'xaxis.range[1]': '2024-05-29 23:59:30', 'yaxis.range[0]': 67521.025, 'yaxis.range[1]': 67828.475}
# relayout_store: {'xaxis.range[0]': '2024-05-29 21:48:18.833', 'xaxis.range[1]': '2024-05-29 23:59:30', 'yaxis.range[0]': 67521.025, 'yaxis.range[1]': 67828.475}
# update_graph started
# no update_graph because of scrolling
# Server received: not scrolling
# update_graph started
# create_figure started
# create_figure completed
# Server received: scrolling
# relayoutData: {'xaxis.range[0]': '2024-05-29 22:01:06.271', 'xaxis.range[1]': '2024-05-29 23:59:30', 'yaxis.range[0]': 67521.025, 'yaxis.range[1]': 67828.475}
# relayout_store: {'xaxis.range[0]': '2024-05-29 22:01:06.271', 'xaxis.range[1]': '2024-05-29 23:59:30', 'yaxis.range[0]': 67521.025, 'yaxis.range[1]': 67828.475}
# relayoutData: {'xaxis.range[0]': '2024-05-29 22:07:01.457', 'xaxis.range[1]': '2024-05-29 23:59:30', 'yaxis.range[0]': 67521.025, 'yaxis.range[1]': 67828.475}
# relayout_store: {'xaxis.range[0]': '2024-05-29 22:07:01.457', 'xaxis.range[1]': '2024-05-29 23:59:30', 'yaxis.range[0]': 67521.025, 'yaxis.range[1]': 67828.475}
# update_graph started
# no update_graph because of scrolling
# Server received: not scrolling
# update_graph started
# create_figure started
# create_figure completed
# Server received: scrolling
# relayoutData: {'xaxis.range[0]': '2024-05-29 22:17:59.439', 'xaxis.range[1]': '2024-05-29 23:59:30', 'yaxis.range[0]': 67521.025, 'yaxis.range[1]': 67828.475}
# relayout_store: {'xaxis.range[0]': '2024-05-29 22:17:59.439', 'xaxis.range[1]': '2024-05-29 23:59:30', 'yaxis.range[0]': 67521.025, 'yaxis.range[1]': 67828.475}
# relayoutData: {'xaxis.range[0]': '2024-05-29 22:23:03.967', 'xaxis.range[1]': '2024-05-29 23:59:30', 'yaxis.range[0]': 67521.025, 'yaxis.range[1]': 67828.475}
# relayout_store: {'xaxis.range[0]': '2024-05-29 22:23:03.967', 'xaxis.range[1]': '2024-05-29 23:59:30', 'yaxis.range[0]': 67521.025, 'yaxis.range[1]': 67828.475}
# update_graph started
# no update_graph because of scrolling
# Server received: not scrolling
# update_graph started
# create_figure started
# create_figure completed
# relayoutData: {'xaxis.range[0]': '2024-05-29 22:37:52.3096', 'xaxis.range[1]': '2024-05-30 00:14:18.3426', 'xaxis2.range[0]': '2024-05-29 22:37:52.3096', 'xaxis2.range[1]': '2024-05-30 00:14:18.3426', 'yaxis.range[0]': 67521.025, 'yaxis.range[1]': 67828.475}
# relayout_store: {'xaxis.range[0]': '2024-05-29 22:37:52.3096', 'xaxis.range[1]': '2024-05-30 00:14:18.3426', 'yaxis.range[0]': 67521.025, 'yaxis.range[1]': 67828.475}
# update_graph started
# create_figure started
# create_figure completed
# relayoutData: {'xaxis.range[0]': '2024-05-29 22:19:05.7636', 'xaxis.range[1]': '2024-05-29 23:55:31.7966', 'xaxis2.range[0]': '2024-05-29 22:19:05.7636', 'xaxis2.range[1]': '2024-05-29 23:55:31.7966', 'yaxis.range[0]': 67501.17832421628, 'yaxis.range[1]': 67808.62832421629}
# relayout_store: {'xaxis.range[0]': '2024-05-29 22:19:05.7636', 'xaxis.range[1]': '2024-05-29 23:55:31.7966', 'yaxis.range[0]': 67501.17832421628, 'yaxis.range[1]': 67808.62832421629}
# update_graph started
# create_figure started
# create_figure completed
# relayoutData: {'xaxis.range[0]': '2024-05-29 21:56:33.5845', 'xaxis.range[1]': '2024-05-29 23:32:59.6175', 'xaxis2.range[0]': '2024-05-29 21:56:33.5845', 'xaxis2.range[1]': '2024-05-29 23:32:59.6175', 'yaxis.range[0]': 67507.05882074479, 'yaxis.range[1]': 67814.5088207448}
# relayout_store: {'xaxis.range[0]': '2024-05-29 21:56:33.5845', 'xaxis.range[1]': '2024-05-29 23:32:59.6175', 'yaxis.range[0]': 67507.05882074479, 'yaxis.range[1]': 67814.5088207448}
# update_graph started
# create_figure started
# create_figure completed
# Server received: scrolling
# relayoutData: {'xaxis.range[0]': '2024-05-29 22:06:12.186', 'xaxis.range[1]': '2024-05-29 23:42:38.219', 'yaxis.range[0]': 67521.025, 'yaxis.range[1]': 67828.475}
# relayout_store: {'xaxis.range[0]': '2024-05-29 22:06:12.186', 'xaxis.range[1]': '2024-05-29 23:42:38.219', 'yaxis.range[0]': 67521.025, 'yaxis.range[1]': 67828.475}
# relayoutData: {'xaxis.range[0]': '2024-05-29 22:15:50.788', 'xaxis.range[1]': '2024-05-29 23:52:16.821', 'yaxis.range[0]': 67521.025, 'yaxis.range[1]': 67828.475}
# relayout_store: {'xaxis.range[0]': '2024-05-29 22:15:50.788', 'xaxis.range[1]': '2024-05-29 23:52:16.821', 'yaxis.range[0]': 67521.025, 'yaxis.range[1]': 67828.475}
# relayoutData: {'xaxis.range[0]': '2024-05-29 22:20:40.089', 'xaxis.range[1]': '2024-05-29 23:57:06.122', 'yaxis.range[0]': 67521.025, 'yaxis.range[1]': 67828.475}
# relayout_store: {'xaxis.range[0]': '2024-05-29 22:20:40.089', 'xaxis.range[1]': '2024-05-29 23:57:06.122', 'yaxis.range[0]': 67521.025, 'yaxis.range[1]': 67828.475}
# update_graph started
# no update_graph because of scrolling
# Server received: not scrolling
# update_graph started
# create_figure started
# create_figure completed
# Server received: scrollingrelayoutData: {'xaxis.range[0]': '2024-05-29 22:15:50.787', 'xaxis.range[1]': '2024-05-29 23:52:16.820', 'yaxis.range[0]': 67521.025, 'yaxis.range[1]': 67828.475}
# relayout_store: {'xaxis.range[0]': '2024-05-29 22:15:50.787', 'xaxis.range[1]': '2024-05-29 23:52:16.820', 'yaxis.range[0]': 67521.025, 'yaxis.range[1]': 67828.475}
#
# relayoutData: {'xaxis.range[0]': '2024-05-29 22:06:12.183', 'xaxis.range[1]': '2024-05-29 23:42:38.216', 'yaxis.range[0]': 67521.025, 'yaxis.range[1]': 67828.475}
# relayout_store: {'xaxis.range[0]': '2024-05-29 22:06:12.183', 'xaxis.range[1]': '2024-05-29 23:42:38.216', 'yaxis.range[0]': 67521.025, 'yaxis.range[1]': 67828.475}
# update_graph started
# no update_graph because of scrolling
# relayoutData: {'xaxis.range[0]': '2024-05-29 22:01:22.881', 'xaxis.range[1]': '2024-05-29 23:37:48.914', 'yaxis.range[0]': 67521.025, 'yaxis.range[1]': 67828.475}
# relayout_store: {'xaxis.range[0]': '2024-05-29 22:01:22.881', 'xaxis.range[1]': '2024-05-29 23:37:48.914', 'yaxis.range[0]': 67521.025, 'yaxis.range[1]': 67828.475}
# update_graph started
# no update_graph because of scrolling
# Server received: not scrolling
# update_graph started
# create_figure started
# create_figure completed
# Server received: scrolling
# relayoutData: {'xaxis.range[0]': '2024-05-29 21:56:33.579', 'xaxis.range[1]': '2024-05-29 23:32:59.612', 'yaxis.range[0]': 67574.575, 'yaxis.range[1]': 67825.925}
# relayout_store: {'xaxis.range[0]': '2024-05-29 21:56:33.579', 'xaxis.range[1]': '2024-05-29 23:32:59.612', 'yaxis.range[0]': 67574.575, 'yaxis.range[1]': 67825.925}
# relayoutData: {'xaxis.range[0]': '2024-05-29 21:46:54.975', 'xaxis.range[1]': '2024-05-29 23:23:21.008', 'yaxis.range[0]': 67574.575, 'yaxis.range[1]': 67825.925}
# relayout_store: {'xaxis.range[0]': '2024-05-29 21:46:54.975', 'xaxis.range[1]': '2024-05-29 23:23:21.008', 'yaxis.range[0]': 67574.575, 'yaxis.range[1]': 67825.925}
# relayoutData: {'xaxis.range[0]': '2024-05-29 21:42:05.673', 'xaxis.range[1]': '2024-05-29 23:18:31.706', 'yaxis.range[0]': 67569.85, 'yaxis.range[1]': 67826.15}
# relayout_store: {'xaxis.range[0]': '2024-05-29 21:42:05.673', 'xaxis.range[1]': '2024-05-29 23:18:31.706', 'yaxis.range[0]': 67569.85, 'yaxis.range[1]': 67826.15}
# update_graph started
# no update_graph because of scrolling
# relayoutData: {'xaxis.range[0]': '2024-05-29 21:37:16.371', 'xaxis.range[1]': '2024-05-29 23:13:42.404', 'yaxis.range[0]': 67520.5, 'yaxis.range[1]': 67828.5}
# relayout_store: {'xaxis.range[0]': '2024-05-29 21:37:16.371', 'xaxis.range[1]': '2024-05-29 23:13:42.404', 'yaxis.range[0]': 67520.5, 'yaxis.range[1]': 67828.5}
# relayoutData: {'xaxis.range[0]': '2024-05-29 21:32:27.069', 'xaxis.range[1]': '2024-05-29 23:08:53.102', 'yaxis.range[0]': 67492.675, 'yaxis.range[1]': 67829.825}
# relayout_store: {'xaxis.range[0]': '2024-05-29 21:32:27.069', 'xaxis.range[1]': '2024-05-29 23:08:53.102', 'yaxis.range[0]': 67492.675, 'yaxis.range[1]': 67829.825}
# relayoutData: {'xaxis.range[0]': '2024-05-29 21:27:37.767', 'xaxis.range[1]': '2024-05-29 23:04:03.800', 'yaxis.range[0]': 67273.225, 'yaxis.range[1]': 67840.275}
# relayout_store: {'xaxis.range[0]': '2024-05-29 21:27:37.767', 'xaxis.range[1]': '2024-05-29 23:04:03.800', 'yaxis.range[0]': 67273.225, 'yaxis.range[1]': 67840.275}
# update_graph started
# no update_graph because of scrolling
# Server received: not scrolling
# update_graph started
# create_figure started
# create_figure completed
# Server received: scrolling
# relayoutData: {'xaxis.range[0]': '2024-05-29 21:17:59.163', 'xaxis.range[1]': '2024-05-29 22:54:25.196', 'yaxis.range[0]': 67273.225, 'yaxis.range[1]': 67840.275}
# relayout_store: {'xaxis.range[0]': '2024-05-29 21:17:59.163', 'xaxis.range[1]': '2024-05-29 22:54:25.196', 'yaxis.range[0]': 67273.225, 'yaxis.range[1]': 67840.275}
# update_graph started
# no update_graph because of scrolling
# Server received: not scrolling
# update_graph started
# create_figure started
# create_figure completed
# Server received: scrolling
# relayoutData: {'xaxis.range[0]': '2024-05-29 21:08:20.559', 'xaxis.range[1]': '2024-05-29 22:44:46.592', 'yaxis.range[0]': 67273.225, 'yaxis.range[1]': 67840.275}
# relayout_store: {'xaxis.range[0]': '2024-05-29 21:08:20.559', 'xaxis.range[1]': '2024-05-29 22:44:46.592', 'yaxis.range[0]': 67273.225, 'yaxis.range[1]': 67840.275}
# update_graph started
# no update_graph because of scrolling
# Server received: not scrolling
# update_graph started
# create_figure started
# create_figure completed
# Server received: scrolling
# relayoutData: {'xaxis.range[0]': '2024-05-29 21:03:31.257', 'xaxis.range[1]': '2024-05-29 22:39:57.290', 'yaxis.range[0]': 67273.225, 'yaxis.range[1]': 67840.275}
# relayout_store: {'xaxis.range[0]': '2024-05-29 21:03:31.257', 'xaxis.range[1]': '2024-05-29 22:39:57.290', 'yaxis.range[0]': 67273.225, 'yaxis.range[1]': 67840.275}
# relayoutData: {'xaxis.range[0]': '2024-05-29 20:58:41.955', 'xaxis.range[1]': '2024-05-29 22:35:07.988', 'yaxis.range[0]': 67273.225, 'yaxis.range[1]': 67840.275}
# relayout_store: {'xaxis.range[0]': '2024-05-29 20:58:41.955', 'xaxis.range[1]': '2024-05-29 22:35:07.988', 'yaxis.range[0]': 67273.225, 'yaxis.range[1]': 67840.275}
# relayoutData: {'xaxis.range[0]': '2024-05-29 20:58:41.955', 'xaxis.range[1]': '2024-05-29 22:35:07.988', 'yaxis.range[0]': 67273.225, 'yaxis.range[1]': 67840.275}
# relayout_store: {'xaxis.range[0]': '2024-05-29 20:58:41.955', 'xaxis.range[1]': '2024-05-29 22:35:07.988', 'yaxis.range[0]': 67273.225, 'yaxis.range[1]': 67840.275}
# update_graph started
# no update_graph because of scrolling
# relayoutData: {'xaxis.range[0]': '2024-05-29 20:53:52.653', 'xaxis.range[1]': '2024-05-29 22:30:18.686', 'yaxis.range[0]': 67273.225, 'yaxis.range[1]': 67840.275}
# relayout_store: {'xaxis.range[0]': '2024-05-29 20:53:52.653', 'xaxis.range[1]': '2024-05-29 22:30:18.686', 'yaxis.range[0]': 67273.225, 'yaxis.range[1]': 67840.275}
# Server received: not scrolling
# relayoutData: {'xaxis.range[0]': '2024-05-29 20:49:03.351', 'xaxis.range[1]': '2024-05-29 22:25:29.384', 'yaxis.range[0]': 67273.225, 'yaxis.range[1]': 67840.275}
# relayout_store: {'xaxis.range[0]': '2024-05-29 20:49:03.351', 'xaxis.range[1]': '2024-05-29 22:25:29.384', 'yaxis.range[0]': 67273.225, 'yaxis.range[1]': 67840.275}
# update_graph started
# create_figure started
# create_figure completed
# Server received: scrolling
# relayoutData: {'xaxis.range[0]': '2024-05-29 20:44:14.049', 'xaxis.range[1]': '2024-05-29 22:20:40.082', 'yaxis.range[0]': 67274.05, 'yaxis.range[1]': 67822.95}
# relayout_store: {'xaxis.range[0]': '2024-05-29 20:44:14.049', 'xaxis.range[1]': '2024-05-29 22:20:40.082', 'yaxis.range[0]': 67274.05, 'yaxis.range[1]': 67822.95}
# Server received: not scrolling
# relayoutData: {'xaxis.range[0]': '2024-05-29 20:39:24.747', 'xaxis.range[1]': '2024-05-29 22:15:50.780', 'yaxis.range[0]': 67274.05, 'yaxis.range[1]': 67822.95}
# relayout_store: {'xaxis.range[0]': '2024-05-29 20:39:24.747', 'xaxis.range[1]': '2024-05-29 22:15:50.780', 'yaxis.range[0]': 67274.05, 'yaxis.range[1]': 67822.95}
# update_graph started
# create_figure started
# create_figure completed
# Server received: scrolling
# relayoutData: {'xaxis.range[0]': '2024-05-29 20:34:35.445', 'xaxis.range[1]': '2024-05-29 22:11:01.478', 'yaxis.range[0]': 67274.05, 'yaxis.range[1]': 67822.95}
# relayout_store: {'xaxis.range[0]': '2024-05-29 20:34:35.445', 'xaxis.range[1]': '2024-05-29 22:11:01.478', 'yaxis.range[0]': 67274.05, 'yaxis.range[1]': 67822.95}
# Server received: not scrolling
# relayoutData: {'xaxis.range[0]': '2024-05-29 20:29:46.143', 'xaxis.range[1]': '2024-05-29 22:06:12.176', 'yaxis.range[0]': 67264.6, 'yaxis.range[1]': 67823.4}
# relayout_store: {'xaxis.range[0]': '2024-05-29 20:29:46.143', 'xaxis.range[1]': '2024-05-29 22:06:12.176', 'yaxis.range[0]': 67264.6, 'yaxis.range[1]': 67823.4}
# update_graph started
# create_figure started
# create_figure completed
# Server received: scrolling
# relayoutData: {'xaxis.range[0]': '2024-05-29 20:24:56.841', 'xaxis.range[1]': '2024-05-29 22:01:22.874', 'yaxis.range[0]': 67149.625, 'yaxis.range[1]': 67828.875}
# relayout_store: {'xaxis.range[0]': '2024-05-29 20:24:56.841', 'xaxis.range[1]': '2024-05-29 22:01:22.874', 'yaxis.range[0]': 67149.625, 'yaxis.range[1]': 67828.875}
# Server received: not scrolling
# relayoutData: {'xaxis.range[0]': '2024-05-29 20:20:07.539', 'xaxis.range[1]': '2024-05-29 21:56:33.572', 'yaxis.range[0]': 67149.625, 'yaxis.range[1]': 67828.875}
# relayout_store: {'xaxis.range[0]': '2024-05-29 20:20:07.539', 'xaxis.range[1]': '2024-05-29 21:56:33.572', 'yaxis.range[0]': 67149.625, 'yaxis.range[1]': 67828.875}
# update_graph started
# create_figure started
# create_figure completed
# Server received: scrolling
# relayoutData: {'xaxis.range[0]': '2024-05-29 20:15:18.237', 'xaxis.range[1]': '2024-05-29 21:51:44.270', 'yaxis.range[0]': 67149.625, 'yaxis.range[1]': 67828.875}
# relayout_store: {'xaxis.range[0]': '2024-05-29 20:15:18.237', 'xaxis.range[1]': '2024-05-29 21:51:44.270', 'yaxis.range[0]': 67149.625, 'yaxis.range[1]': 67828.875}
# Server received: not scrolling
# relayoutData: {'xaxis.range[0]': '2024-05-29 20:10:28.935', 'xaxis.range[1]': '2024-05-29 21:46:54.968', 'yaxis.range[0]': 67157.45, 'yaxis.range[1]': 67664.55}
# relayout_store: {'xaxis.range[0]': '2024-05-29 20:10:28.935', 'xaxis.range[1]': '2024-05-29 21:46:54.968', 'yaxis.range[0]': 67157.45, 'yaxis.range[1]': 67664.55}
# relayoutData: {'xaxis.range[0]': '2024-05-29 20:05:39.633', 'xaxis.range[1]': '2024-05-29 21:42:05.666', 'yaxis.range[0]': 67110.725, 'yaxis.range[1]': 67666.775}
# relayout_store: {'xaxis.range[0]': '2024-05-29 20:05:39.633', 'xaxis.range[1]': '2024-05-29 21:42:05.666', 'yaxis.range[0]': 67110.725, 'yaxis.range[1]': 67666.775}
# relayoutData: {'xaxis.range[0]': '2024-05-29 20:00:50.331', 'xaxis.range[1]': '2024-05-29 21:37:16.364', 'yaxis.range[0]': 67113.375, 'yaxis.range[1]': 67611.125}
# relayout_store: {'xaxis.range[0]': '2024-05-29 20:00:50.331', 'xaxis.range[1]': '2024-05-29 21:37:16.364', 'yaxis.range[0]': 67113.375, 'yaxis.range[1]': 67611.125}
# update_graph started
# create_figure started
# create_figure completed
# Server received: scrollingrelayoutData: {'xaxis.range[0]': '2024-05-29 19:56:01.029', 'xaxis.range[1]': '2024-05-29 21:32:27.062', 'yaxis.range[0]': 67114.275, 'yaxis.range[1]': 67592.225}
# relayout_store: {'xaxis.range[0]': '2024-05-29 19:56:01.029', 'xaxis.range[1]': '2024-05-29 21:32:27.062', 'yaxis.range[0]': 67114.275, 'yaxis.range[1]': 67592.225}
#
# relayoutData: {'xaxis.range[0]': '2024-05-29 19:51:11.727', 'xaxis.range[1]': '2024-05-29 21:27:37.760', 'yaxis.range[0]': 67116, 'yaxis.range[1]': 67556}
# relayout_store: {'xaxis.range[0]': '2024-05-29 19:51:11.727', 'xaxis.range[1]': '2024-05-29 21:27:37.760', 'yaxis.range[0]': 67116, 'yaxis.range[1]': 67556}
# Server received: not scrolling
# relayoutData: {'xaxis.range[0]': '2024-05-29 19:46:22.425', 'xaxis.range[1]': '2024-05-29 21:22:48.458', 'yaxis.range[0]': 67117.925, 'yaxis.range[1]': 67515.575}
# relayout_store: {'xaxis.range[0]': '2024-05-29 19:46:22.425', 'xaxis.range[1]': '2024-05-29 21:22:48.458', 'yaxis.range[0]': 67117.925, 'yaxis.range[1]': 67515.575}
# update_graph started
# create_figure started
# create_figure completed
# Server received: scrolling
# relayoutData: {'xaxis.range[0]': '2024-05-29 19:41:33.123', 'xaxis.range[1]': '2024-05-29 21:17:59.156', 'yaxis.range[0]': 67117.925, 'yaxis.range[1]': 67515.575}
# relayout_store: {'xaxis.range[0]': '2024-05-29 19:41:33.123', 'xaxis.range[1]': '2024-05-29 21:17:59.156', 'yaxis.range[0]': 67117.925, 'yaxis.range[1]': 67515.575}
# relayoutData: {'xaxis.range[0]': '2024-05-29 19:36:43.821', 'xaxis.range[1]': '2024-05-29 21:13:09.854', 'yaxis.range[0]': 67115, 'yaxis.range[1]': 67577}
# relayout_store: {'xaxis.range[0]': '2024-05-29 19:36:43.821', 'xaxis.range[1]': '2024-05-29 21:13:09.854', 'yaxis.range[0]': 67115, 'yaxis.range[1]': 67577}
# relayoutData: {'xaxis.range[0]': '2024-05-29 19:31:54.519', 'xaxis.range[1]': '2024-05-29 21:08:20.552', 'yaxis.range[0]': 67112.025, 'yaxis.range[1]': 67639.475}
# relayout_store: {'xaxis.range[0]': '2024-05-29 19:31:54.519', 'xaxis.range[1]': '2024-05-29 21:08:20.552', 'yaxis.range[0]': 67112.025, 'yaxis.range[1]': 67639.475}
# update_graph started
# no update_graph because of scrolling
# Server received: not scrolling
# update_graph started
# create_figure started
# create_figure completed
# Server received: scrolling
# relayoutData: {'xaxis.range[0]': '2024-05-29 19:27:05.217', 'xaxis.range[1]': '2024-05-29 21:08:20.552', 'yaxis.range[0]': 67106.775, 'yaxis.range[1]': 67749.725}
# relayout_store: {'xaxis.range[0]': '2024-05-29 19:27:05.217', 'xaxis.range[1]': '2024-05-29 21:08:20.552', 'yaxis.range[0]': 67106.775, 'yaxis.range[1]': 67749.725}
# update_graph started
# no update_graph because of scrolling
# relayoutData: {'xaxis.range[0]': '2024-05-29 19:22:01.450', 'xaxis.range[1]': '2024-05-29 21:08:20.552', 'yaxis.range[0]': 67106.775, 'yaxis.range[1]': 67749.725}
# relayout_store: {'xaxis.range[0]': '2024-05-29 19:22:01.450', 'xaxis.range[1]': '2024-05-29 21:08:20.552', 'yaxis.range[0]': 67106.775, 'yaxis.range[1]': 67749.725}
# update_graph started
# no update_graph because of scrolling
# relayoutData: {'xaxis.range[0]': '2024-05-29 19:16:42.494', 'xaxis.range[1]': '2024-05-29 21:08:20.552', 'yaxis.range[0]': 67106.775, 'yaxis.range[1]': 67749.725}
# relayout_store: {'xaxis.range[0]': '2024-05-29 19:16:42.494', 'xaxis.range[1]': '2024-05-29 21:08:20.552', 'yaxis.range[0]': 67106.775, 'yaxis.range[1]': 67749.725}
# update_graph started
# no update_graph because of scrolling
# Server received: not scrolling
# update_graph started
# create_figure started
# create_figure completed
# Server received: scrolling
# relayoutData: {'xaxis.range[0]': '2024-05-29 19:05:15.942', 'xaxis.range[1]': '2024-05-29 21:08:20.552', 'yaxis.range[0]': 67106.775, 'yaxis.range[1]': 67749.725}
# relayout_store: {'xaxis.range[0]': '2024-05-29 19:05:15.942', 'xaxis.range[1]': '2024-05-29 21:08:20.552', 'yaxis.range[0]': 67106.775, 'yaxis.range[1]': 67749.725}
# relayoutData: {'xaxis.range[0]': '2024-05-29 18:52:39.018', 'xaxis.range[1]': '2024-05-29 21:08:20.552', 'yaxis.range[0]': 67106.775, 'yaxis.range[1]': 67749.725}
# relayout_store: {'xaxis.range[0]': '2024-05-29 18:52:39.018', 'xaxis.range[1]': '2024-05-29 21:08:20.552', 'yaxis.range[0]': 67106.775, 'yaxis.range[1]': 67749.725}
# update_graph started
# no update_graph because of scrolling
# Server received: not scrolling
# update_graph started
# create_figure started
# create_figure completed
# Server received: scrolling
# relayoutData: {'xaxis.range[0]': '2024-05-29 19:11:07.591', 'xaxis.range[1]': '2024-05-29 21:08:20.552', 'yaxis.range[0]': 67106.775, 'yaxis.range[1]': 67749.725}
# relayout_store: {'xaxis.range[0]': '2024-05-29 19:11:07.591', 'xaxis.range[1]': '2024-05-29 21:08:20.552', 'yaxis.range[0]': 67106.775, 'yaxis.range[1]': 67749.725}
# relayoutData: {'xaxis.range[0]': '2024-05-29 19:05:15.942', 'xaxis.range[1]': '2024-05-29 21:08:20.552', 'yaxis.range[0]': 67106.775, 'yaxis.range[1]': 67749.725}
# relayout_store: {'xaxis.range[0]': '2024-05-29 19:05:15.942', 'xaxis.range[1]': '2024-05-29 21:08:20.552', 'yaxis.range[0]': 67106.775, 'yaxis.range[1]': 67749.725}
# relayoutData: {'xaxis.range[0]': '2024-05-29 18:59:06.711', 'xaxis.range[1]': '2024-05-29 21:08:20.552', 'yaxis.range[0]': 67106.775, 'yaxis.range[1]': 67749.725}
# relayout_store: {'xaxis.range[0]': '2024-05-29 18:59:06.711', 'xaxis.range[1]': '2024-05-29 21:08:20.552', 'yaxis.range[0]': 67106.775, 'yaxis.range[1]': 67749.725}
# relayoutData: {'xaxis.range[0]': '2024-05-29 18:45:51.941', 'xaxis.range[1]': '2024-05-29 21:08:20.552', 'yaxis.range[0]': 67106.775, 'yaxis.range[1]': 67749.725}
# relayout_store: {'xaxis.range[0]': '2024-05-29 18:45:51.941', 'xaxis.range[1]': '2024-05-29 21:08:20.552', 'yaxis.range[0]': 67106.775, 'yaxis.range[1]': 67749.725}
# relayoutData: {'xaxis.range[0]': '2024-05-29 18:38:44.510', 'xaxis.range[1]': '2024-05-29 21:08:20.552', 'yaxis.range[0]': 67106.775, 'yaxis.range[1]': 67749.725}
# relayout_store: {'xaxis.range[0]': '2024-05-29 18:38:44.510', 'xaxis.range[1]': '2024-05-29 21:08:20.552', 'yaxis.range[0]': 67106.775, 'yaxis.range[1]': 67749.725}
# update_graph started
# no update_graph because of scrolling
# relayoutData: {'xaxis.range[0]': '2024-05-29 18:15:09.659', 'xaxis.range[1]': '2024-05-29 21:08:20.552', 'yaxis.range[0]': 67106.775, 'yaxis.range[1]': 67749.725}
# relayout_store: {'xaxis.range[0]': '2024-05-29 18:15:09.659', 'xaxis.range[1]': '2024-05-29 21:08:20.552', 'yaxis.range[0]': 67106.775, 'yaxis.range[1]': 67749.725}
# Server received: not scrolling
# relayoutData: {'xaxis.range[0]': '2024-05-29 18:06:30.114', 'xaxis.range[1]': '2024-05-29 21:08:20.552', 'yaxis.range[0]': 67106.775, 'yaxis.range[1]': 67749.725}
# relayout_store: {'xaxis.range[0]': '2024-05-29 18:06:30.114', 'xaxis.range[1]': '2024-05-29 21:08:20.552', 'yaxis.range[0]': 67106.775, 'yaxis.range[1]': 67749.725}
# update_graph started
# create_figure started
# create_figure completed
# Server received: scrolling
# relayoutData: {'xaxis.range[0]': '2024-05-29 17:57:24.592', 'xaxis.range[1]': '2024-05-29 21:08:20.552', 'yaxis.range[0]': 67106.775, 'yaxis.range[1]': 67749.725}
# relayout_store: {'xaxis.range[0]': '2024-05-29 17:57:24.592', 'xaxis.range[1]': '2024-05-29 21:08:20.552', 'yaxis.range[0]': 67106.775, 'yaxis.range[1]': 67749.725}
# Server received: not scrolling
# relayoutData: {'xaxis.range[0]': '2024-05-29 17:47:51.794', 'xaxis.range[1]': '2024-05-29 21:08:20.552', 'yaxis.range[0]': 67106.775, 'yaxis.range[1]': 67749.725}
# relayout_store: {'xaxis.range[0]': '2024-05-29 17:47:51.794', 'xaxis.range[1]': '2024-05-29 21:08:20.552', 'yaxis.range[0]': 67106.775, 'yaxis.range[1]': 67749.725}
# relayoutData: {'xaxis.range[0]': '2024-05-29 17:37:50.356', 'xaxis.range[1]': '2024-05-29 21:08:20.552', 'yaxis.range[0]': 67106.775, 'yaxis.range[1]': 67749.725}
# relayout_store: {'xaxis.range[0]': '2024-05-29 17:37:50.356', 'xaxis.range[1]': '2024-05-29 21:08:20.552', 'yaxis.range[0]': 67106.775, 'yaxis.range[1]': 67749.725}
# update_graph started
# create_figure started
# create_figure completed
# relayoutData: {'xaxis.range[0]': '2024-05-29 17:27:18.846', 'xaxis.range[1]': '2024-05-29 21:08:20.552', 'yaxis.range[0]': 67106.775, 'yaxis.range[1]': 67749.725}
# relayout_store: {'xaxis.range[0]': '2024-05-29 17:27:18.846', 'xaxis.range[1]': '2024-05-29 21:08:20.552', 'yaxis.range[0]': 67106.775, 'yaxis.range[1]': 67749.725}
# relayoutData: {'xaxis.range[0]': '2024-05-29 17:16:15.760', 'xaxis.range[1]': '2024-05-29 21:08:20.552', 'yaxis.range[0]': 67106.775, 'yaxis.range[1]': 67749.725}
# relayout_store: {'xaxis.range[0]': '2024-05-29 17:16:15.760', 'xaxis.range[1]': '2024-05-29 21:08:20.552', 'yaxis.range[0]': 67106.775, 'yaxis.range[1]': 67749.725}
# relayoutData: {'xaxis.range[0]': '2024-05-29 17:04:39.520', 'xaxis.range[1]': '2024-05-29 21:08:20.552', 'yaxis.range[0]': 67106.775, 'yaxis.range[1]': 67749.725}
# relayout_store: {'xaxis.range[0]': '2024-05-29 17:04:39.520', 'xaxis.range[1]': '2024-05-29 21:08:20.552', 'yaxis.range[0]': 67106.775, 'yaxis.range[1]': 67749.725}
# relayoutData: {'xaxis.range[0]': '2024-05-29 16:52:28.468', 'xaxis.range[1]': '2024-05-29 21:08:20.552', 'yaxis.range[0]': 67106.775, 'yaxis.range[1]': 67749.725}
# relayout_store: {'xaxis.range[0]': '2024-05-29 16:52:28.468', 'xaxis.range[1]': '2024-05-29 21:08:20.552', 'yaxis.range[0]': 67106.775, 'yaxis.range[1]': 67749.725}
# update_graph started
# create_figure started
# create_figure completed
# relayoutData: {'xaxis.range[0]': '2024-05-29 16:39:40.863', 'xaxis.range[1]': '2024-05-29 21:08:20.552', 'yaxis.range[0]': 67106.775, 'yaxis.range[1]': 67749.725}
# relayout_store: {'xaxis.range[0]': '2024-05-29 16:39:40.863', 'xaxis.range[1]': '2024-05-29 21:08:20.552', 'yaxis.range[0]': 67106.775, 'yaxis.range[1]': 67749.725}
# relayoutData: {'xaxis.range[0]': '2024-05-29 16:26:14.878', 'xaxis.range[1]': '2024-05-29 21:08:20.552', 'yaxis.range[0]': 67106.775, 'yaxis.range[1]': 67749.725}
# relayout_store: {'xaxis.range[0]': '2024-05-29 16:26:14.878', 'xaxis.range[1]': '2024-05-29 21:08:20.552', 'yaxis.range[0]': 67106.775, 'yaxis.range[1]': 67749.725}
# update_graph started
# create_figure started
# create_figure completed
# Server received: scrolling
# relayoutData: {'xaxis.range[0]': '2024-05-29 16:12:08.594', 'xaxis.range[1]': '2024-05-29 21:08:20.552', 'yaxis.range[0]': 67106.775, 'yaxis.range[1]': 67749.725}
# relayout_store: {'xaxis.range[0]': '2024-05-29 16:12:08.594', 'xaxis.range[1]': '2024-05-29 21:08:20.552', 'yaxis.range[0]': 67106.775, 'yaxis.range[1]': 67749.725}
# relayoutData: {'xaxis.range[0]': '2024-05-29 15:57:19.996', 'xaxis.range[1]': '2024-05-29 21:08:20.552', 'yaxis.range[0]': 67106.25, 'yaxis.range[1]': 67749.75}
# relayout_store: {'xaxis.range[0]': '2024-05-29 15:57:19.996', 'xaxis.range[1]': '2024-05-29 21:08:20.552', 'yaxis.range[0]': 67106.25, 'yaxis.range[1]': 67749.75}
# update_graph started
# no update_graph because of scrolling
# Server received: not scrolling
# update_graph started
# create_figure started
# create_figure completed
# Server received: scrolling
# relayoutData: {'xaxis.range[0]': '2024-05-29 15:25:27.288', 'xaxis.range[1]': '2024-05-29 21:08:20.552', 'yaxis.range[0]': 67101.525, 'yaxis.range[1]': 67848.975}
# relayout_store: {'xaxis.range[0]': '2024-05-29 15:25:27.288', 'xaxis.range[1]': '2024-05-29 21:08:20.552', 'yaxis.range[0]': 67101.525, 'yaxis.range[1]': 67848.975}
# Server received: not scrolling
# update_graph started
# create_figure started
# create_figure completed
# Server received: scrolling
# relayoutData: {'xaxis.range[0]': '2024-05-29 14:50:18.527', 'xaxis.range[1]': '2024-05-29 21:08:20.552', 'yaxis.range[0]': 67099.775, 'yaxis.range[1]': 67885.725}
# relayout_store: {'xaxis.range[0]': '2024-05-29 14:50:18.527', 'xaxis.range[1]': '2024-05-29 21:08:20.552', 'yaxis.range[0]': 67099.775, 'yaxis.range[1]': 67885.725}
# update_graph started
# no update_graph because of scrolling
# Server received: not scrolling
# update_graph started
# create_figure started
# create_figure completed
# Server received: scrolling
# relayoutData: {'xaxis.range[0]': '2024-05-29 14:31:24.425', 'xaxis.range[1]': '2024-05-29 21:08:20.552', 'yaxis.range[0]': 67099.775, 'yaxis.range[1]': 67885.725}
# relayout_store: {'xaxis.range[0]': '2024-05-29 14:31:24.425', 'xaxis.range[1]': '2024-05-29 21:08:20.552', 'yaxis.range[0]': 67099.775, 'yaxis.range[1]': 67885.725}
# relayoutData: {'xaxis.range[0]': '2024-05-29 13:28:50.406', 'xaxis.range[1]': '2024-05-29 21:08:20.552', 'yaxis.range[0]': 67093.525, 'yaxis.range[1]': 68016.975}
# relayout_store: {'xaxis.range[0]': '2024-05-29 13:28:50.406', 'xaxis.range[1]': '2024-05-29 21:08:20.552', 'yaxis.range[0]': 67093.525, 'yaxis.range[1]': 68016.975}
# update_graph started
# no update_graph because of scrolling
# Server received: not scrolling
# update_graph started
# create_figure started
# create_figure completed
# Server received: scrolling
# relayoutData: {'xaxis.range[0]': '2024-05-29 12:41:44.465', 'xaxis.range[1]': '2024-05-29 21:08:20.552', 'yaxis.range[0]': 67077.425, 'yaxis.range[1]': 68355.075}
# relayout_store: {'xaxis.range[0]': '2024-05-29 12:41:44.465', 'xaxis.range[1]': '2024-05-29 21:08:20.552', 'yaxis.range[0]': 67077.425, 'yaxis.range[1]': 68355.075}
# relayoutData: {'xaxis.range[0]': '2024-05-29 12:16:24.660', 'xaxis.range[1]': '2024-05-29 21:08:20.552', 'yaxis.range[0]': 67077.425, 'yaxis.range[1]': 68355.075}
# relayout_store: {'xaxis.range[0]': '2024-05-29 12:16:24.660', 'xaxis.range[1]': '2024-05-29 21:08:20.552', 'yaxis.range[0]': 67077.425, 'yaxis.range[1]': 68355.075}
# relayoutData: {'xaxis.range[0]': '2024-05-29 11:49:48.865', 'xaxis.range[1]': '2024-05-29 21:08:20.552', 'yaxis.range[0]': 67077.425, 'yaxis.range[1]': 68355.075}
# relayout_store: {'xaxis.range[0]': '2024-05-29 11:49:48.865', 'xaxis.range[1]': '2024-05-29 21:08:20.552', 'yaxis.range[0]': 67077.425, 'yaxis.range[1]': 68355.075}
# relayoutData: {'xaxis.range[0]': '2024-05-29 11:21:53.280', 'xaxis.range[1]': '2024-05-29 21:08:20.552', 'yaxis.range[0]': 67077.425, 'yaxis.range[1]': 68355.075}
# relayout_store: {'xaxis.range[0]': '2024-05-29 11:21:53.280', 'xaxis.range[1]': '2024-05-29 21:08:20.552', 'yaxis.range[0]': 67077.425, 'yaxis.range[1]': 68355.075}
# update_graph started
# no update_graph because of scrolling
# Server received: not scrolling
# update_graph started
# create_figure started
# create_figure completed
# ...
# relayoutData: {'xaxis.range[0]': '2024-05-23 07:51:29.905', 'xaxis.range[1]': '2024-05-23 23:55:07.508', 'yaxis.range[0]': 65914.3, 'yaxis.range[1]': 70329.7}
# relayout_store: {'xaxis.range[0]': '2024-05-23 07:51:29.905', 'xaxis.range[1]': '2024-05-23 23:55:07.508', 'yaxis.range[0]': 65914.3, 'yaxis.range[1]': 70329.7}
# update_graph started
# no update_graph because of scrolling
# relayoutData: {'xaxis.range[0]': '2024-05-23 07:52:40.933', 'xaxis.range[1]': '2024-05-23 22:19:56.776', 'yaxis.range[0]': 65914.3, 'yaxis.range[1]': 70329.7}
# relayout_store: {'xaxis.range[0]': '2024-05-23 07:52:40.933', 'xaxis.range[1]': '2024-05-23 22:19:56.776', 'yaxis.range[0]': 65914.3, 'yaxis.range[1]': 70329.7}
# update_graph started
# no update_graph because of scrolling
# relayoutData: {'xaxis.range[0]': '2024-05-23 07:53:44.859', 'xaxis.range[1]': '2024-05-23 20:54:17.117', 'yaxis.range[0]': 65914.3, 'yaxis.range[1]': 70329.7}
# relayout_store: {'xaxis.range[0]': '2024-05-23 07:53:44.859', 'xaxis.range[1]': '2024-05-23 20:54:17.117', 'yaxis.range[0]': 65914.3, 'yaxis.range[1]': 70329.7}
# relayoutData: {'xaxis.range[0]': '2024-05-23 07:54:42.392', 'xaxis.range[1]': '2024-05-23 19:37:11.424', 'yaxis.range[0]': 66523.3, 'yaxis.range[1]': 70300.7}
# relayout_store: {'xaxis.range[0]': '2024-05-23 07:54:42.392', 'xaxis.range[1]': '2024-05-23 19:37:11.424', 'yaxis.range[0]': 66523.3, 'yaxis.range[1]': 70300.7}
# update_graph started
# no update_graph because of scrolling
# Server received: not scrolling
# update_graph started
# create_figure started
# create_figure completed
# Server received: scrolling
# relayoutData: {'xaxis.range[0]': '2024-05-23 07:55:34.172', 'xaxis.range[1]': '2024-05-23 18:27:48.300', 'yaxis.range[0]': 66523.3, 'yaxis.range[1]': 70300.7}
# relayout_store: {'xaxis.range[0]': '2024-05-23 07:55:34.172', 'xaxis.range[1]': '2024-05-23 18:27:48.300', 'yaxis.range[0]': 66523.3, 'yaxis.range[1]': 70300.7}
# relayoutData: {'xaxis.range[0]': '2024-05-23 07:56:20.774', 'xaxis.range[1]': '2024-05-23 17:25:21.489', 'yaxis.range[0]': 67478.8, 'yaxis.range[1]': 70255.2}
# relayout_store: {'xaxis.range[0]': '2024-05-23 07:56:20.774', 'xaxis.range[1]': '2024-05-23 17:25:21.489', 'yaxis.range[0]': 67478.8, 'yaxis.range[1]': 70255.2}
# update_graph started
# no update_graph because of scrolling
# relayoutData: {'xaxis.range[0]': '2024-05-23 07:57:02.715', 'xaxis.range[1]': '2024-05-23 16:29:09.359', 'yaxis.range[0]': 67478.8, 'yaxis.range[1]': 70255.2}
# relayout_store: {'xaxis.range[0]': '2024-05-23 07:57:02.715', 'xaxis.range[1]': '2024-05-23 16:29:09.359', 'yaxis.range[0]': 67478.8, 'yaxis.range[1]': 70255.2}
# update_graph started
# no update_graph because of scrolling
# Server received: not scrolling
# update_graph started
# create_figure started
# create_figure completed
# update_graph started
# create_figure started
# create_figure completed
# Server received: scrolling
# relayoutData: {'xaxis.range[0]': '2024-05-23 08:52:54.460', 'xaxis.range[1]': '2024-05-23 15:47:43.042', 'yaxis.range[0]': 67478.8, 'yaxis.range[1]': 70255.2}
# relayout_store: {'xaxis.range[0]': '2024-05-23 08:52:54.460', 'xaxis.range[1]': '2024-05-23 15:47:43.042', 'yaxis.range[0]': 67478.8, 'yaxis.range[1]': 70255.2}
# relayoutData: {'xaxis.range[0]': '2024-05-23 09:37:32.683', 'xaxis.range[1]': '2024-05-23 15:13:32.434', 'yaxis.range[0]': 67478.8, 'yaxis.range[1]': 70255.2}
# relayout_store: {'xaxis.range[0]': '2024-05-23 09:37:32.683', 'xaxis.range[1]': '2024-05-23 15:13:32.434', 'yaxis.range[0]': 67478.8, 'yaxis.range[1]': 70255.2}
# relayoutData: {'xaxis.range[0]': '2024-05-23 09:56:13.769', 'xaxis.range[1]': '2024-05-23 14:58:37.545', 'yaxis.range[0]': 67478.8, 'yaxis.range[1]': 70255.2}
# relayout_store: {'xaxis.range[0]': '2024-05-23 09:56:13.769', 'xaxis.range[1]': '2024-05-23 14:58:37.545', 'yaxis.range[0]': 67478.8, 'yaxis.range[1]': 70255.2}
# update_graph started
# no update_graph because of scrolling
# Server received: not scrolling
# update_graph started
# create_figure started
# create_figure completed
# Server received: scrolling
# relayoutData: {'xaxis.range[0]': '2024-05-23 10:39:54.288', 'xaxis.range[1]': '2024-05-23 14:44:50.746', 'yaxis.range[0]': 67512.4, 'yaxis.range[1]': 70253.6}
# relayout_store: {'xaxis.range[0]': '2024-05-23 10:39:54.288', 'xaxis.range[1]': '2024-05-23 14:44:50.746', 'yaxis.range[0]': 67512.4, 'yaxis.range[1]': 70253.6}
# relayoutData: {'xaxis.range[0]': '2024-05-23 10:58:57.747', 'xaxis.range[1]': '2024-05-23 14:39:24.559', 'yaxis.range[0]': 67512.4, 'yaxis.range[1]': 70253.6}
# relayout_store: {'xaxis.range[0]': '2024-05-23 10:58:57.747', 'xaxis.range[1]': '2024-05-23 14:39:24.559', 'yaxis.range[0]': 67512.4, 'yaxis.range[1]': 70253.6}
# update_graph started
# no update_graph because of scrolling
# relayoutData: {'xaxis.range[0]': '2024-05-23 11:16:06.860', 'xaxis.range[1]': '2024-05-23 14:34:30.990', 'yaxis.range[0]': 67512.4, 'yaxis.range[1]': 70253.6}
# relayout_store: {'xaxis.range[0]': '2024-05-23 11:16:06.860', 'xaxis.range[1]': '2024-05-23 14:34:30.990', 'yaxis.range[0]': 67512.4, 'yaxis.range[1]': 70253.6}
# update_graph started
# no update_graph because of scrolling
# relayoutData: {'xaxis.range[0]': '2024-05-23 11:31:33.061', 'xaxis.range[1]': '2024-05-23 14:30:06.778', 'yaxis.range[0]': 67512.4, 'yaxis.range[1]': 70253.6}
# relayout_store: {'xaxis.range[0]': '2024-05-23 11:31:33.061', 'xaxis.range[1]': '2024-05-23 14:30:06.778', 'yaxis.range[0]': 67512.4, 'yaxis.range[1]': 70253.6}
# update_graph started
# no update_graph because of scrolling
# Server received: not scrolling
# update_graph started
# create_figure started
# create_figure completed
# Server received: scrolling
# relayoutData: {'xaxis.range[0]': '2024-05-23 11:57:56.865', 'xaxis.range[1]': '2024-05-23 14:22:34.975', 'yaxis.range[0]': 67512.4, 'yaxis.range[1]': 70253.6}
# relayout_store: {'xaxis.range[0]': '2024-05-23 11:57:56.865', 'xaxis.range[1]': '2024-05-23 14:22:34.975', 'yaxis.range[0]': 67512.4, 'yaxis.range[1]': 70253.6}
# relayoutData: {'xaxis.range[0]': '2024-05-23 12:09:12.066', 'xaxis.range[1]': '2024-05-23 14:19:22.365', 'yaxis.range[0]': 67515.225, 'yaxis.range[1]': 70194.275}
# relayout_store: {'xaxis.range[0]': '2024-05-23 12:09:12.066', 'xaxis.range[1]': '2024-05-23 14:19:22.365', 'yaxis.range[0]': 67515.225, 'yaxis.range[1]': 70194.275}
# update_graph started
# no update_graph because of scrolling
# Server received: not scrolling
# update_graph started
# create_figure started
# create_figure completed
# Server received: scrolling
# relayoutData: {'xaxis.range[0]': '2024-05-23 12:19:19.746', 'xaxis.range[1]': '2024-05-23 14:16:29.016', 'yaxis.range[0]': 67515.225, 'yaxis.range[1]': 70194.275}
# relayout_store: {'xaxis.range[0]': '2024-05-23 12:19:19.746', 'xaxis.range[1]': '2024-05-23 14:16:29.016', 'yaxis.range[0]': 67515.225, 'yaxis.range[1]': 70194.275}
# relayoutData: {'xaxis.range[0]': '2024-05-23 12:28:26.658', 'xaxis.range[1]': '2024-05-23 14:13:53.001', 'yaxis.range[0]': 67518.95, 'yaxis.range[1]': 70116.05}
# relayout_store: {'xaxis.range[0]': '2024-05-23 12:28:26.658', 'xaxis.range[1]': '2024-05-23 14:13:53.001', 'yaxis.range[0]': 67518.95, 'yaxis.range[1]': 70116.05}
# update_graph started
# no update_graph because of scrolling
# Server received: not scrolling
# update_graph started
# create_figure started
# create_figure completed
# update_graph started
# create_figure started
# create_figure completed
# Server received: scrollingrelayoutData: {'xaxis.range[0]': '2024-05-23 12:33:42.975', 'xaxis.range[1]': '2024-05-23 14:13:53.001', 'yaxis.range[0]': 67520.3, 'yaxis.range[1]': 70087.7}
# relayout_store: {'xaxis.range[0]': '2024-05-23 12:33:42.975', 'xaxis.range[1]': '2024-05-23 14:13:53.001', 'yaxis.range[0]': 67520.3, 'yaxis.range[1]': 70087.7}
#
# update_graph started
# no update_graph because of scrolling
# Server received: not scrolling
# update_graph started
# create_figure started
# create_figure completed
# Server received: scrolling
# relayoutData: {'xaxis.range[0]': '2024-05-23 12:23:26.946', 'xaxis.range[1]': '2024-05-23 14:13:53.001', 'yaxis.range[0]': 67515.225, 'yaxis.range[1]': 70194.275}
# relayout_store: {'xaxis.range[0]': '2024-05-23 12:23:26.946', 'xaxis.range[1]': '2024-05-23 14:13:53.001', 'yaxis.range[0]': 67515.225, 'yaxis.range[1]': 70194.275}
# update_graph started
# no update_graph because of scrolling
# relayoutData: {'xaxis.range[0]': '2024-05-23 12:17:55.643', 'xaxis.range[1]': '2024-05-23 14:13:53.001', 'yaxis.range[0]': 67515.225, 'yaxis.range[1]': 70194.275}
# relayout_store: {'xaxis.range[0]': '2024-05-23 12:17:55.643', 'xaxis.range[1]': '2024-05-23 14:13:53.001', 'yaxis.range[0]': 67515.225, 'yaxis.range[1]': 70194.275}
# update_graph started
# no update_graph because of scrolling
# relayoutData: {'xaxis.range[0]': '2024-05-23 12:06:02.513', 'xaxis.range[1]': '2024-05-23 14:13:53.001', 'yaxis.range[0]': 67512.4, 'yaxis.range[1]': 70253.6}
# relayout_store: {'xaxis.range[0]': '2024-05-23 12:06:02.513', 'xaxis.range[1]': '2024-05-23 14:13:53.001', 'yaxis.range[0]': 67512.4, 'yaxis.range[1]': 70253.6}
# update_graph started
# no update_graph because of scrolling
# Server received: not scrolling
# update_graph started
# create_figure started
# create_figure completed
# relayoutData: {'xaxis.range[0]': '2024-05-23 12:15:32.3519', 'xaxis.range[1]': '2024-05-23 14:23:22.8399', 'xaxis2.range[0]': '2024-05-23 12:15:32.3519', 'xaxis2.range[1]': '2024-05-23 14:23:22.8399', 'yaxis.range[0]': 67512.4, 'yaxis.range[1]': 70253.6}
# relayout_store: {'xaxis.range[0]': '2024-05-23 12:15:32.3519', 'xaxis.range[1]': '2024-05-23 14:23:22.8399', 'yaxis.range[0]': 67512.4, 'yaxis.range[1]': 70253.6}
# update_graph started
# create_figure started
# create_figure completed
# relayoutData: {'xaxis.range[0]': '2024-05-23 12:21:55.875', 'xaxis.range[1]': '2024-05-23 14:29:46.363', 'yaxis.range[0]': 67515.225, 'yaxis.range[1]': 70194.275}
# relayout_store: {'xaxis.range[0]': '2024-05-23 12:21:55.875', 'xaxis.range[1]': '2024-05-23 14:29:46.363', 'yaxis.range[0]': 67515.225, 'yaxis.range[1]': 70194.275}
# Server received: scrolling
# relayoutData: {'xaxis.range[0]': '2024-05-23 12:34:42.923', 'xaxis.range[1]': '2024-05-23 14:42:33.411', 'yaxis.range[0]': 67520.65, 'yaxis.range[1]': 70080.35}
# relayout_store: {'xaxis.range[0]': '2024-05-23 12:34:42.923', 'xaxis.range[1]': '2024-05-23 14:42:33.411', 'yaxis.range[0]': 67520.65, 'yaxis.range[1]': 70080.35}
# update_graph started
# no update_graph because of scrolling
# relayoutData: {'xaxis.range[0]': '2024-05-23 12:41:06.447', 'xaxis.range[1]': '2024-05-23 14:48:56.935', 'yaxis.range[0]': 67523.55, 'yaxis.range[1]': 70019.45}
# relayout_store: {'xaxis.range[0]': '2024-05-23 12:41:06.447', 'xaxis.range[1]': '2024-05-23 14:48:56.935', 'yaxis.range[0]': 67523.55, 'yaxis.range[1]': 70019.45}
# update_graph started
# no update_graph because of scrolling
# Server received: not scrolling
# update_graph started
# create_figure started
# create_figure completed
# Server received: scrolling
# relayoutData: {'xaxis.range[0]': '2024-05-23 12:28:19.397', 'xaxis.range[1]': '2024-05-23 14:36:09.885', 'yaxis.range[0]': 67518.95, 'yaxis.range[1]': 70116.05}
# relayout_store: {'xaxis.range[0]': '2024-05-23 12:28:19.397', 'xaxis.range[1]': '2024-05-23 14:36:09.885', 'yaxis.range[0]': 67518.95, 'yaxis.range[1]': 70116.05}
# relayoutData: {'xaxis.range[0]': '2024-05-23 12:21:55.872', 'xaxis.range[1]': '2024-05-23 14:29:46.360', 'yaxis.range[0]': 67515.225, 'yaxis.range[1]': 70194.275}
# relayout_store: {'xaxis.range[0]': '2024-05-23 12:21:55.872', 'xaxis.range[1]': '2024-05-23 14:29:46.360', 'yaxis.range[0]': 67515.225, 'yaxis.range[1]': 70194.275}
# relayoutData: {'xaxis.range[0]': '2024-05-23 12:15:32.347', 'xaxis.range[1]': '2024-05-23 14:23:22.835', 'yaxis.range[0]': 67515.225, 'yaxis.range[1]': 70194.275}
# relayout_store: {'xaxis.range[0]': '2024-05-23 12:15:32.347', 'xaxis.range[1]': '2024-05-23 14:23:22.835', 'yaxis.range[0]': 67515.225, 'yaxis.range[1]': 70194.275}
# update_graph started
# no update_graph because of scrolling
# Server received: not scrolling
# update_graph started
# create_figure started
# create_figure completed
# Server received: scrolling
# relayoutData: {'xaxis.range[0]': '2024-05-23 12:02:26.121', 'xaxis.range[1]': '2024-05-23 14:23:22.835', 'yaxis.range[0]': 67512.4, 'yaxis.range[1]': 70253.6}
# relayout_store: {'xaxis.range[0]': '2024-05-23 12:02:26.121', 'xaxis.range[1]': '2024-05-23 14:23:22.835', 'yaxis.range[0]': 67512.4, 'yaxis.range[1]': 70253.6}
# relayoutData: {'xaxis.range[0]': '2024-05-23 11:55:23.285', 'xaxis.range[1]': '2024-05-23 14:23:22.835', 'yaxis.range[0]': 67512.4, 'yaxis.range[1]': 70253.6}
# relayout_store: {'xaxis.range[0]': '2024-05-23 11:55:23.285', 'xaxis.range[1]': '2024-05-23 14:23:22.835', 'yaxis.range[0]': 67512.4, 'yaxis.range[1]': 70253.6}
# relayoutData: {'xaxis.range[0]': '2024-05-23 11:47:59.307', 'xaxis.range[1]': '2024-05-23 14:23:22.835', 'yaxis.range[0]': 67512.4, 'yaxis.range[1]': 70253.6}
# relayout_store: {'xaxis.range[0]': '2024-05-23 11:47:59.307', 'xaxis.range[1]': '2024-05-23 14:23:22.835', 'yaxis.range[0]': 67512.4, 'yaxis.range[1]': 70253.6}
# relayoutData: {'xaxis.range[0]': '2024-05-23 11:40:13.130', 'xaxis.range[1]': '2024-05-23 14:23:22.835', 'yaxis.range[0]': 67512.4, 'yaxis.range[1]': 70253.6}
# relayout_store: {'xaxis.range[0]': '2024-05-23 11:40:13.130', 'xaxis.range[1]': '2024-05-23 14:23:22.835', 'yaxis.range[0]': 67512.4, 'yaxis.range[1]': 70253.6}
# update_graph started
# no update_graph because of scrolling
# Server received: not scrolling
# update_graph started
# create_figure started
# create_figure completed
# Server received: scrolling
# relayoutData: {'xaxis.range[0]': '2024-05-23 11:32:03.644', 'xaxis.range[1]': '2024-05-23 14:23:22.835', 'yaxis.range[0]': 67512.4, 'yaxis.range[1]': 70253.6}
# relayout_store: {'xaxis.range[0]': '2024-05-23 11:32:03.644', 'xaxis.range[1]': '2024-05-23 14:23:22.835', 'yaxis.range[0]': 67512.4, 'yaxis.range[1]': 70253.6}
# update_graph started
# no update_graph because of scrolling
# Server received: not scrolling
# update_graph started
# create_figure started
# create_figure completed
# Server received: scrolling
# relayoutData: {'xaxis.range[0]': '2024-05-23 11:23:29.684', 'xaxis.range[1]': '2024-05-23 14:23:22.835', 'yaxis.range[0]': 67512.4, 'yaxis.range[1]': 70253.6}
# relayout_store: {'xaxis.range[0]': '2024-05-23 11:23:29.684', 'xaxis.range[1]': '2024-05-23 14:23:22.835', 'yaxis.range[0]': 67512.4, 'yaxis.range[1]': 70253.6}
# update_graph started
# no update_graph because of scrolling
# relayoutData: {'xaxis.range[0]': '2024-05-23 11:14:30.026', 'xaxis.range[1]': '2024-05-23 14:23:22.835', 'yaxis.range[0]': 67512.4, 'yaxis.range[1]': 70253.6}
# relayout_store: {'xaxis.range[0]': '2024-05-23 11:14:30.026', 'xaxis.range[1]': '2024-05-23 14:23:22.835', 'yaxis.range[0]': 67512.4, 'yaxis.range[1]': 70253.6}
# update_graph started
# no update_graph because of scrolling
# relayoutData: {'xaxis.range[0]': '2024-05-23 11:05:03.385', 'xaxis.range[1]': '2024-05-23 14:23:22.835', 'yaxis.range[0]': 67512.4, 'yaxis.range[1]': 70253.6}
# relayout_store: {'xaxis.range[0]': '2024-05-23 11:05:03.385', 'xaxis.range[1]': '2024-05-23 14:23:22.835', 'yaxis.range[0]': 67512.4, 'yaxis.range[1]': 70253.6}
# update_graph started
# no update_graph because of scrolling
# relayoutData: {'xaxis.range[0]': '2024-05-23 10:55:08.412', 'xaxis.range[1]': '2024-05-23 14:23:22.835', 'yaxis.range[0]': 67512.4, 'yaxis.range[1]': 70253.6}
# relayout_store: {'xaxis.range[0]': '2024-05-23 10:55:08.412', 'xaxis.range[1]': '2024-05-23 14:23:22.835', 'yaxis.range[0]': 67512.4, 'yaxis.range[1]': 70253.6}
# update_graph started
# no update_graph because of scrolling
# relayoutData: {'xaxis.range[0]': '2024-05-23 10:44:43.690', 'xaxis.range[1]': '2024-05-23 14:23:22.835', 'yaxis.range[0]': 67512.4, 'yaxis.range[1]': 70253.6}
# relayout_store: {'xaxis.range[0]': '2024-05-23 10:44:43.690', 'xaxis.range[1]': '2024-05-23 14:23:22.835', 'yaxis.range[0]': 67512.4, 'yaxis.range[1]': 70253.6}
# update_graph started
# no update_graph because of scrolling
# Server received: not scrolling
# update_graph started
# create_figure started
# create_figure completed
